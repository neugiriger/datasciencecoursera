# %% [markdown]
# <a href="https://colab.research.google.com/github/neugiriger/datasciencecoursera/blob/master/IontheFoldDataCuration_directfromdrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Data Curation -  Bulk downloading of structural files from the PDB**

# %% [markdown]
# This notebook performs automated bulk downloading of 3D structural data from the RCSB Protein Data Bank (PDB). It is part of the data curation process for protein design and analysis, specifically focusing on structures that will later be screened for charged protein–protein interfaces.
#
# The shell script (batch_download.sh) leverages the RCSB’s programmatic access API to download various file formats including:
#
# *   .cif.gz: standard mmCIF structure format ; Contains full atom details, experimental methods, symmetry, and model info. This is requried for Accurate residue mapping and atom coordinates for structures from recent deposits.
#
# *   .pdb.gz: legacy PDB format ;Used for structure preprocessing for input to ProteinMPNN. Extracts chain IDs, residue sequences, and backbone coordinates.
#
# *   sf.cif.gz: structure factor files (used in crystallographic analysis). This is required for Contains diffraction data used to compute the 3D structure (X-ray crystallography).
#
# Allows validation of the atomic model (e.g., checking charge density around binding sites).
#
#
# To prevent data loss from Colab session timeouts, all files are downloaded directly to Google Drive.
#
# Protein IDs used for the extract has been downloaded from RCSB Protein Data Bank (PDB) https://www.rcsb.org/search/advanced and the bulk extract script from https://www.rcsb.org/docs/programmatic-access/batch-downloads-with-shell-script

# %% [markdown]
# # 1. Start here: Mount Google Drive
#
# This enables saving large downloaded files persistently, even if the Colab session disconnects or expires

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2. Import Libraries
#
# Just run this cell so everything below works. You'll need to rerun it if you start the runtime again.

# %%
from google.colab import drive
import os
import ipywidgets as widgets
from IPython.display import display
from IPython.display import clear_output

# %% [markdown]
# # 2. Load in required files from Googledrive (Ion the Fold)
#
# Adjust the file locations as you need

# %%
# Link to the protein ID file in google drive
inputProteinFile = '/content/drive/MyDrive/IonTheFold/CodesandWorkingFiles/CollectingProteins/Input_PDBIDs/testproteins.txt'

# Link to  the batch download file
batchDownloadFile = '/content/drive/MyDrive/IonTheFold/CodesandWorkingFiles/CollectingProteins/batch_download.sh'

# Link to  the output location where the protein files of each ID in the ID file will be saved
outputLocationFolder = '/content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/0-10k' # this could be any one of the folders from 1-10k to 10-20k, 10-30k and so on up to 170-180k

# %% [markdown]
# #3. Set base directories in google drive

# %%
# Set base directories

# Link to the protein ID file folder in google drive (general)
input_base = "/content/drive/MyDrive/IonTheFold/CodesandWorkingFiles/CollectingProteins/Input_PDBIDs"

# Link to  the batch download file
batchDownloadFile = '/content/drive/MyDrive/IonTheFold/CodesandWorkingFiles/CollectingProteins/batch_download.sh'

# Link to  the output location where the protein files of each ID in the ID file will be saved
output_base = "/content/drive/MyDrive/IonTheFold/ProteinInformation_RAW"


# and we will check they are all working
if os.path.isdir(input_base):
    print(f"✅ Input folder found: {input_base}")
    print("   Contents:", os.listdir(input_base)[:5])
else:
    print(f"❌ Input folder not found: {input_base}")

if os.path.isfile(batchDownloadFile):
    print(f"✅ Batch script found: {batchDownloadFile}")
else:
    print(f"❌ Batch script NOT found: {batchDownloadFile}")

if os.path.isdir(output_base):
    print(f"✅ Output folder found: {output_base}")
    print("   Subfolders:", os.listdir(output_base)[:5])
else:
    print(f"❌ Output folder not found: {output_base}")
# Out:
# ✅ Input folder found: /content/drive/MyDrive/IonTheFold/CodesandWorkingFiles/CollectingProteins/Input_PDBIDs
#    Contents: ['testproteins.txt', 'pdb_ids_1-10000.txt', 'pdb_IDs_20001-30000.txt', 'pdb_ids_10001-20000.txt', 'pdb_ids_30001-40000.txt']
# ✅ Batch script found: /content/drive/MyDrive/IonTheFold/CodesandWorkingFiles/CollectingProteins/batch_download.sh
# ✅ Output folder found: /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW
#    Subfolders: ['20-30k', '10-20k', '30-40k', '40-50k', 'testCollection']

# %% [markdown]
# #4a. Check what's already been done
#
# Run this script to see what's already been done in the drive. Make sure you're not overlapping

# %%
import os
import pandas as pd

# Base directory
base_dir = "/content/drive/MyDrive/IonTheFold/ProteinInformation_RAW"

# Prepare a list to store results
folder_counts = []

# Loop through subfolders and count files
for subfolder in sorted(os.listdir(base_dir)):
    subfolder_path = os.path.join(base_dir, subfolder)
    if os.path.isdir(subfolder_path):
        count = sum(
            os.path.isfile(os.path.join(subfolder_path, f))
            for f in os.listdir(subfolder_path)
        )
        folder_counts.append((subfolder, count))

# Convert to DataFrame and display
df = pd.DataFrame(folder_counts, columns=["Subfolder", "File Count"])
print(df.to_string(index=False))
# Out:
#       Subfolder  File Count
#           1-10k           1
#          10-20k           5
#          20-30k           5
#          30-40k           1
#          40-50k       14444
#          50-60k           1
#          60-70k           2
#          70-80k           2
#  testCollection           1
# testCollection2           0

# %% [markdown]
# # 4b. Select the protein set you would like to process.
#
# This function will make sure the right folders are set up to grab the protein file you want, extract the protein IDs and then make sure the output is going to the right folder.
#
# Each has 10k proteins and will take about 8 hours. Make sure you select your protein set from the dropdown list below after you run this cell.
#
# Once you've run this, go into Google Drive folder "ProteinInformation_RAW" under your selected folder and check the test file is there. This is only a test file with just the first few proteins IDs copied in, just so we know this set up is working.

# %%
# Define dropdown options (manual mapping based on your folder structure)
id_file_options = {
    "1-10k": "pdb_ids_1-10000.txt",
    "10-20k": "pdb_ids_10001-20000.txt",
    "20-30k": "pdb_ids_20001-30000.txt",
    "30-40k": "pdb_ids_30001-40000.txt",
    "40-50k": "pdb_ids_40001-50000.txt",
    "50-60k": "pdb_ids_50001-60000.txt",
    "60-70k": "pdb_ids_60001-70000.txt",
    "70-80k": "pdb_ids_70001-80000.txt",
    #"80-90k": "pdb_ids_80001-90000.txt",
    #"90-1000k": "pdb_ids_90001-1000000.txt",
    #"100-110k": "pdb_ids_100001-110000.txt",
    #"110-120k": "pdb_ids_110001-120000.txt",
    #"120-130k": "pdb_ids_120001-130000.txt",
    #"130-140k": "pdb_ids_130001-140000.txt",
    #"140-150k": "pdb_ids_140001-150000.txt",
    #"150-160k": "pdb_ids_150001-160000.txt",
    #"160-170k": "pdb_ids_160001-170000.txt",
    #"170-180k": "pdb_ids_170001-180000.txt",
    #"180-188k": "pdb_ids_180001-188000.txt",
    "Test file": "testproteins.txt"
}

# Dropdown widget for user selection
dropdown = widgets.Dropdown(
    options=list(id_file_options.keys()),
    value="Test file",
    description='Protein Set:',
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='50%')
)

display(dropdown)

# Handler function to run once selection is made
def validate_selection(change):
    from IPython.display import clear_output
    clear_output(wait=True)
    label = change.new
    input_file = os.path.join(input_base, id_file_options[label])

    # Match folder name to ID range label
    folder_key = "testCollection" if label == "Test file" else label
    output_dir = os.path.join(output_base, folder_key)

    print(f"\n📄 Selected ID File: {input_file}")
    print(f"📁 Matched Output Folder: {output_dir}")

    # Check existence
    assert os.path.exists(input_file), "❌ ID file does not exist."
    assert os.path.isdir(output_dir), "❌ Output folder does not exist."
    print("✅ Both input and output paths are valid.")

    # Read first protein ID
    with open(input_file, 'r') as f:
        for line in f:
            first_id = line.strip()
            if first_id:
                break

    print(f"First Protein ID: {first_id}")

    # Auto-name test file
    base_name = "testProteinWrite"
    ext = ".txt"
    i = 1
    while os.path.exists(os.path.join(output_dir, f"{base_name}{i}{ext}")):
        i += 1
    test_file_path = os.path.join(output_dir, f"{base_name}{i}{ext}")

    # Write file
    with open(test_file_path, 'w') as f:
        f.write(f"This is a test file for protein ID: {first_id}\n")

    print(f"✅ Test file written as: {test_file_path}")

# Register the handler
dropdown.observe(validate_selection, names='value')
# Out:
# 📄 Selected ID File: /content/drive/MyDrive/IonTheFold/CodesandWorkingFiles/CollectingProteins/Input_PDBIDs/pdb_ids_40001-50000.txt
# 📁 Matched Output Folder: /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k
# ✅ Both input and output paths are valid.
# First Protein ID: 7DWW,7DXR,7DXS,7DXT,7DXU,7DXV,7DXW,7DXX,7DXY,7DXZ,7DYC,7E24,7E28,7E3X,7EBS,7EBX,7EC0,7EK8,7EK9,7EQL,7EUM,7EVY,7K3P,7K44,7K6G,7K87,7K9N,7K9O,7K9Q,7K9T,7KA1,7KLK,7KLL,7KLM,7KV0,7LM5,7LTC,7LTE,7LTF,7LTH,7LTR,7LTS,7LX6,7M16,7MBF,7MCE,7MJ2,7MKJ,7MLC,7MLD,7MLY,7MY9,7MYA,7MYB,7MYC,7N3J,7NVJ,7NVK,7NW1,7NXV,7OSK,7P4M,7P4P,7P4Q,7PBG,7PBI,7PI4,7PN0,7PNR,7POP,7POR,7POS,7POT,7R66,7RBR,7RBS,7RBZ,7RC0,7RC1,7RCL,7RCM,7RCO,7RFD,7RII,7RZL,7RZP,7S49,7S4C,7S5A,7S87,5SBK,5SBL,5SBM,5SBN,5SBO,5SBP,5SBQ,5SBR,5SBS,5SBT,5SBU,5SBV,5SBW,5SBX,5SBY,5SBZ,5SC0,5SC1,5SC2,5SC3,5SC4,5SC5,5SC6,5SC7,6M63,6X1C,6X1E,6X1F,7BGG,7BID,7BIE,7BIF,7BIG,7BLY,7CZ9,7D1X,7D2F,7D2W,7D31,7D32,7D33,7DAI,7DAJ,7DAK,7DAL,7DHA,7E4W,7E6G,7F3Y,7F3Z,7JTA,7JUA,7JZ9,7JZA,7JZB,7JZC,7JZD,7JZE,7JZF,7JZG,7K03,7K0B,7K0D,7K0U,7K1E,7K1F,7K1P,7K27,7K3O,7K42,7K5A,7K6F,7K6H,7K77,7K8B,7K8E,7K8F,7K8H,7K8K,7K8L,7KE0,7KN3,7KN4,7KSN,7KX6,7L2H,7L2P,7L2S,7L4L,7L8H,7L8I,7L8J,7LLD,7LLE,7LM0,7LZ7,7LZ8,7LZB,7LZD,7LZF,7M2L,7M3S,7M98,7MBP,7MPC,7MPD,7MPH,7MQA,7MQJ,7MZ5,7MZ6,7MZD,7NA0,7NDM,7NKZ,7NMK,7NOY,7NUS,7O50,7O86,7OKW,7OY8,7PJE,7PJF,7RB5,7RB6,7RB7,7RIH,7RIJ,7RKS,7RMQ,7RMR,7RMS,7ROV,7RRX,7RS7,7RS8,7S3U,7S3W,7S41,7S42,7S43,7S44,7S45,7S4S,7S5E,7S5M,7S5N,7S66,7S6O,7S6P,7VE3,6KVR,6WIB,6WMH,6WNA,6WOL,7AAW,7AWT,7BIW,7BJ8,7BJB,7BOC,7BYI,7CKN,7CME,7CMF,7CON,7COO,7CP8,7CWW,7CYI,7D0T,7D0U,7D0V,7D1F,7D4K,7D4M,7D4N,7DEX,7DHS,7DJS,7DPT,7DPW,7E3O,7EBD,7EBL,7ET4,7ET5,7ET6,7F26,7F65,7FFT,7FFW,7K1H,7KD3,7KD4,7KO2,7KRT,7KRU,7KRV,7LMY,7LN0,7LOO,7LUR,7LUS,7MBO,7MJV,7MJW,7MJX,7MJY,7MJZ,7MPL,7MPM,7MPN,7MPO,7MPP,7MPQ,7MPR,7MPS,7MPT,7MPU,7MQF,7MTC,7MWS,7MWW,7MYG,7N0L,7N7X,7NG7,7NMH,7NPI,7NYB,7NZJ,7O0M,7O0N,7O0P,7O0Q,7O0R,7O0S,7O1R,7O1X,7O1Z,7O27,7O28,7O2D,7O2G,7O2H,7O3B,7OD1,7OIZ,7OLS,7OLV,7OLX,7ONR,7ONS,7ONT,7OUN,7OX7,7OX8,7OX9,7OXA,7OZM,7P0Y,7P3H,7P3S,7P65,7P68,7P6A,7P6B,7P6C,7PL1,7RAH,7REI,7RFK,7RFL,7RFM,7RFN,7RTY,7S3K,7S3S,7S4B,6WSK,7AJ0,7ARP,7ASZ,7BNK,7BNR,7CVH,7CX6,7CX8,7CYY,7CZ0,7CZC,7CZI,7CZJ,7DDR,7DDS,7DDT,7DDU,7DDX,7DEK,7DP0,7DP1,7DP2,7DRP,7DVE,7E0A,7E5O,7E9S,7EBI,7EBM,7EV5,7F4F,7F4H,7F8K,7FFP,7FG6,7JOR,7JQH,7JQI,7JQJ,7JQR,7JQS,7JQT,7JQU,7JRR,7JT5,7JT6,7JVH,7JVI,7JXL,7JXM,7JXP,7JXQ,7JXW,7KUK,7KUM,7KUN,7KUO,7KUP,7KX0,7L0O,7LHY,7LNE,7LNF,7LNG,7M1Q,7M1R,7MGP,7MGU,7MMX,7MN4,7MPV,7MPX,7MQ6,7MQ7,7N5O,7N5R,7N5X,7N5Y,7N6T,7N6V,7N6X,7N7R,7N7U,7N7W,7N7Y,7N83,7NCX,7NH4,7NH5,7NXL,7NXM,7O06,7O0E,7O3O,7O82,7O8B,7ODA,7P2H,7P2I,7P2J,7P2L,7PDC,7PED,7R89,7R8A,7RAG,7RL1,7RM5,7RN1,7RN5,7RNI,7RRY,7RRZ,7RS0,7RS1,7RS2,7RS3,7RS4,7RS9,7RYX,7RZC,7S0Y,7S0Z,5R42,5R43,5R44,5R45,5R46,5R47,5R48,5R49,5R4A,5R4B,5R4C,5R4D,5SAK,5SAL,5SAM,5SAN,5SAO,5SAP,5SAQ,5SAR,5SAS,5SAT,6VEZ,6VF0,6VF1,6VF2,6VF3,6VF4,6VF5,6VF6,6VF7,6VF8,6VF9,6VFA,6VFB,6VFC,6VTX,6WVX,6X5V,6X5W,6X6M,6X6Q,6Y4A,7A56,7AC2,7AC3,7AC4,7AC5,7AEQ,7AES,7AGN,7AI8,7AI9,7AQS,7B39,7B4I,7B4J,7CTD,7CTL,7CTM,7CV7,7CV8,7CV9,7CVA,7CVR,7CVT,7CVU,7CVV,7CVW,7CWA,7CWF,7CWG,7CWJ,7CWK,7CWP,7CWX,7CWY,7CWZ,7CX0,7CX1,7CX7,7CXA,7CXB,7CXC,7CXD,7CXE,7CXF,7CXG,7CXH,7CXI,7CXJ,7CXK,7CXL,7DBE,7DFY,7DY8,7DY9,7DYA,7DYB,7DYR,7ET1,7EYI,7F2B,7F2R,7FE0,7FE5,7FE6,7JT8,7JUO,7JVS,7JW5,7KE3,7KE5,7KLD,7KW4,7L7D,7L7L,7L7N,7L7O,7L7P,7LBZ,7LCA,7LCG,7LCH,7LCL,7LD2,7LDC,7LDT,7LDU,7LDV,7LDW,7LPO,7LPP,7LPQ,7LY1,7M5U,7M7D,7N3U,7N6B,7N9Z,7NHI,7NI5,7NI6,7NRW,7NSR,7NTP,7O08,7O09,7O0L,7O19,7O1A,7O1C,7O1U,7O1W,7O1Y,7O20,7O22,7O29,7O2E,7O2F,7O60,7O6Z,7ODX,7ODY,7ONJ,7OOA,7OPN,7ORC,7OXZ,7OY4,7PHY,7R7H,7RCT,7REE,7RK0,7RVA,7RY8,7RY9,7RYA,7RYB,6VTO,6VTP,6VTQ,6VTR,6VTS,6WCE,6XER,6XES,6XET,6XZ1,6Z1K,6Z1L,7A1J,7A1K,7A1L,7A1M,7A1N,7A1O,7A1P,7A1Q,7A1S,7A1V,7A28,7A2F,7A2J,7A2K,7A2L,7A2M,7A2N,7A2O,7A2P,7A2Q,7A2R,7A2S,7A2T,7A2U,7A2V,7A2W,7A2X,7A2Y,7A2Z,7A30,7A31,7A32,7A33,7A34,7A35,7A36,7A37,7A38,7A39,7A3A,7A3B,7A3C,7A3D,7A3E,7A3W,7A6R,7A6Y,7AE5,7AE7,7AI3,7ANM,7AP7,7APJ,7BJ9,7BJY,7BM2,7BME,7CKC,7CRG,7CT1,7CT6,7CU9,7CUB,7CUI,7CUJ,7CUQ,7CUV,7CUW,7D1L,7D2Y,7D8B,7D9O,7D9P,7D9Q,7DA6,7DC3,7DE7,7DHQ,7DUF,7E2R,7E2S,7E2T,7E2U,7E56,7EIP,7EIQ,7EIR,7EIS,7EJO,7EJS,7EU2,7EZM,7F4W,7JKW,7JKY,7JKZ,7JQW,7JRE,7JSD,7JSP,7JTC,7JTT,7JUJ,7KYO,7KYP,7L97,7LGU,7LGW,7L ...
# ✅ Test file written as: /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/testProteinWrite2.txt

# %% [markdown]
# #5a. Run the download scripts, with counts on the first 5 protein IDs.
#
# Check that the google drive file contains 15 files. There should be 3 files per protein

# %%
# === Set dynamic paths from dropdown ===
label = dropdown.value
original_file = os.path.join(input_base, id_file_options[label])
output_dir = os.path.join(output_base, "testCollection" if label == "Test file" else label)

# === Reuse batch script path ===
script_path = batchDownloadFile

# === Read the first 5 comma-separated IDs from the original file ===
with open(original_file, 'r') as f:
    content = f.read().strip()
    all_ids = [x.strip() for x in content.split(",") if x.strip()]
    first_5_ids = all_ids[:5]

# === Write the trimmed list to a temporary input file ===
temp_input_file = "/content/first5_ids.txt"
with open(temp_input_file, 'w') as f:
    f.write(",".join(first_5_ids))

print(f"🧪 Running batch download on first 5 IDs: {first_5_ids}")

# === Ensure output directory exists ===
os.makedirs(output_dir, exist_ok=True)

# === Make the script executable ===
# !chmod +x "{script_path}"

# === Run the download script with flags ===
# !bash "{script_path}" -f "{temp_input_file}" -o "{output_dir}" -c -p -s

# Count successfully downloaded *.pdb.gz files (1 per protein ID)
saved_ids = !find "{output_dir}" -type f -name "*.pdb.gz" | wc -l
saved_ids = int(saved_ids[0])
missing = len(first_5_ids) - saved_ids

print("----------------------------------------")
print("Summary (First 5 IDs):")
print(f"Expected PDB IDs:            {len(first_5_ids)}")
print(f"Protein structures saved:    {saved_ids}")
print(f"Missing or failed downloads: {missing}")
print("----------------------------------------")
# Out:
# 🧪 Running batch download on first 5 IDs: ['7DWW', '7DXR', '7DXS', '7DXT', '7DXU']
# Downloading https://files.rcsb.org/download/7DWW.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DWW.cif.gz
# Downloading https://files.rcsb.org/download/7DWW.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DWW.pdb.gz
# Downloading https://files.rcsb.org/download/7DWW-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DWW-sf.cif.gz
# Downloading https://files.rcsb.org/download/7DXR.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DXR.cif.gz
# Downloading https://files.rcsb.org/download/7DXR.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DXR.pdb.gz
# Downloading https://files.rcsb.org/download/7DXR-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DXR-sf.cif.gz
# Downloading https://files.rcsb.org/download/7DXS.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DXS.cif.gz
# Downloading https://files.rcsb.org/download/7DXS.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DXS.pdb.gz
# Downloading https://files.rcsb.org/download/7DXS-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DXS-sf.cif.gz
# Downloading https://files.rcsb.org/download/7DXT.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DXT.cif.gz
# Downloading https://files.rcsb.org/download/7DXT.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DXT.pdb.gz
# Downloading https://files.rcsb.org/download/7DXT-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DXT-sf.cif.gz
# Downloading https://files.rcsb.org/download/7DXU.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DXU.cif.gz
# Downloading https://files.rcsb.org/download/7DXU.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DXU.pdb.gz
# Downloading https://files.rcsb.org/download/7DXU-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DXU-sf.cif.gz
# ----------------------------------------
# Summary (First 5 IDs):
# Expected PDB IDs:            5
# Protein structures saved:    5
# Missing or failed downloads: 0
# ----------------------------------------

# %% [markdown]
# #5b. Now run the rest of the first half of the proteins. (4995 protein ids)
#
# This will take around 6-8 hours.

# %%
# === Reuse dropdown-selected file and output dir from previous cell ===
label = dropdown.value
original_file = os.path.join(input_base, id_file_options[label])
output_dir = os.path.join(output_base, "testCollection" if label == "Test file" else label)
script_path = batchDownloadFile

# === Read IDs 6 to 5000 ===
with open(original_file, 'r') as f:
    content = f.read().strip()
    all_ids = [x.strip() for x in content.split(",") if x.strip()]
    next_4995_ids = all_ids[5:5000]  # Skip first 5

# === Write to temp file ===
temp_input_file = "/content/next4995_ids.txt"
with open(temp_input_file, 'w') as f:
    f.write(",".join(next_4995_ids))

print(f"🧪 Downloading next 4,995 protein IDs from: {label}")

# === Ensure output dir exists ===
os.makedirs(output_dir, exist_ok=True)

# === Run download script ===
# !chmod +x "{script_path}"
# !bash "{script_path}" -f "{temp_input_file}" -o "{output_dir}" -c -p -s

# === Count saved *.pdb.gz files
saved_ids = !find "{output_dir}" -type f -name "*.pdb.gz" | wc -l
saved_ids = int(saved_ids[0])
processed = len(next_4995_ids)
missing = processed - saved_ids

# === Summary
print("----------------------------------------")
print("Summary (IDs 6–5000):")
print(f"Expected PDB IDs:            {processed}")
print(f"Protein structures saved:    {saved_ids}")
print(f"Missing or failed downloads: {missing}")
print("----------------------------------------")
# Out:
# Streaming output truncated to the last 5000 lines.
# Downloading https://files.rcsb.org/download/7O26.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7O26.cif.gz
# Downloading https://files.rcsb.org/download/7O26.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7O26.pdb.gz
# Downloading https://files.rcsb.org/download/7O26-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7O26-sf.cif.gz
# Downloading https://files.rcsb.org/download/7OD7.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7OD7.cif.gz
# Downloading https://files.rcsb.org/download/7OD7.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7OD7.pdb.gz
# Downloading https://files.rcsb.org/download/7OD7-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7OD7-sf.cif.gz
# Failed to download https://files.rcsb.org/download/7OD7-sf.cif.gz
# Downloading https://files.rcsb.org/download/7OEC.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7OEC.cif.gz
# Downloading https://files.rcsb.org/download/7OEC.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7OEC.pdb.gz
# Downloading https://files.rcsb.org/download/7OEC-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7OEC-sf.cif.gz
# Downloading https://files.rcsb.org/download/6RMN.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6RMN.cif.gz
# Downloading https://files.rcsb.org/download/6RMN.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6RMN.pdb.gz
# Downloading https://files.rcsb.org/download/6RMN-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6RMN-sf.cif.gz
# Downloading https://files.rcsb.org/download/6SHX.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6SHX.cif.gz
# Downloading https://files.rcsb.org/download/6SHX.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6SHX.pdb.gz
# Downloading https://files.rcsb.org/download/6SHX-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6SHX-sf.cif.gz
# Downloading https://files.rcsb.org/download/6SNS.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6SNS.cif.gz
# Downloading https://files.rcsb.org/download/6SNS.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6SNS.pdb.gz
# Downloading https://files.rcsb.org/download/6SNS-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6SNS-sf.cif.gz
# Downloading https://files.rcsb.org/download/6SNV.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6SNV.cif.gz
# Downloading https://files.rcsb.org/download/6SNV.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6SNV.pdb.gz
# Downloading https://files.rcsb.org/download/6SNV-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6SNV-sf.cif.gz
# Downloading https://files.rcsb.org/download/6TE3.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6TE3.cif.gz
# Downloading https://files.rcsb.org/download/6TE3.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6TE3.pdb.gz
# Downloading https://files.rcsb.org/download/6TE3-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6TE3-sf.cif.gz
# Downloading https://files.rcsb.org/download/6TEC.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6TEC.cif.gz
# Downloading https://files.rcsb.org/download/6TEC.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6TEC.pdb.gz
# Downloading https://files.rcsb.org/download/6TEC-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6TEC-sf.cif.gz
# Downloading https://files.rcsb.org/download/6TES.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6TES.cif.gz
# Downloading https://files.rcsb.org/download/6TES.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6TES.pdb.gz
# Downloading https://files.rcsb.org/download/6TES-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6TES-sf.cif.gz
# Downloading https://files.rcsb.org/download/6TEX.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6TEX.cif.gz
# Downloading https://files.rcsb.org/download/6TEX.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6TEX.pdb.gz
# Downloading https://files.rcsb.org/download/6TEX-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6TEX-sf.cif.gz
# Downloading https://files.rcsb.org/download/6TEZ.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6TEZ.cif.gz
# Downloading https://files.rcsb.org/download/6TEZ.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6TEZ.pdb.gz
# Downloading https://files.rcsb.org/download/6TEZ-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6TEZ-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WKO.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WKO.cif.gz
# Downloading https://files.rcsb.org/download/6WKO.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WKO.pdb.gz
# Downloading https://files.rcsb.org/download/6WKO-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WKO-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WXN.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WXN.cif.gz
# Downloading https://files.rcsb.org/download/6WXN.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WXN.pdb.gz
# Downloading https://files.rcsb.org/download/6WXN-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WXN-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WYM.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WYM.cif.gz
# Downloading https://files.rcsb.org/download/6WYM.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WYM.pdb.gz
# Downloading https://files.rcsb.org/download/6WYM-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WYM-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WYN.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WYN.cif.gz
# Downloading https://files.rcsb.org/download/6WYN.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WYN.pdb.gz
# Downloading https://files.rcsb.org/download/6WYN-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WYN-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WZP.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WZP.cif.gz
# Downloading https://files.rcsb.org/download/6WZP.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WZP.pdb.gz
# Downloading https://files.rcsb.org/download/6WZP-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WZP-sf.cif.gz
# Downloading https://files.rcsb.org/download/6X0S.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6X0S.cif.gz
# Downloading https://files.rcsb.org/download/6X0S.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6X0S.pdb.gz
# Downloading https://files.rcsb.org/download/6X0S-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6X0S-sf.cif.gz
# Downloading https://files.rcsb.org/download/6X0T.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6X0T.cif.gz
# Downloading https://files.rcsb.org/download/6X0T.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6X0T.pdb.gz
# Downloading https://files.rcsb.org/download/6X0T-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6X0T-sf.cif.gz
# Downloading https://files.rcsb.org/download/6XO2.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XO2.cif.gz
# Downloading https://files.rcsb.org/download/6XO2.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XO2.pdb.gz
# Downloading https://files.rcsb.org/download/6XO2-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XO2-sf.cif.gz
# Downloading https://files.rcsb.org/download/6XPX.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XPX.cif.gz
# Downloading https://files.rcsb.org/download/6XPX.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XPX.pdb.gz
# Downloading https://files.rcsb.org/download/6XPX-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XPX-sf.cif.gz
# Downloading https://files.rcsb.org/download/6XQ0.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XQ0.cif.gz
# Downloading https://files.rcsb.org/download/6XQ0.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XQ0.pdb.gz
# Downloading https://files.rcsb.org/download/6XQ0-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XQ0-sf.cif.gz
# Downloading https://files.rcsb.org/download/6YZH.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YZH.cif.gz
# Downloading https://files.rcsb.org/download/6YZH.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YZH.pdb.gz
# Downloading https://files.rcsb.org/download/6YZH-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YZH-sf.cif.gz
# Downloading https://files.rcsb.org/download/6YZY.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YZY.cif.gz
# Downloading https://files.rcsb.org/download/6YZY.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YZY.pdb.gz
# Failed to download https://files.rcsb.org/download/6YZY.pdb.gz
# Downloading https://files.rcsb.org/download/6YZY-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YZY-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z0E.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0E.cif.gz
# Downloading https://files.rcsb.org/download/6Z0E.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0E.pdb.gz
# Downloading https://files.rcsb.org/download/6Z0E-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0E-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z0F.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0F.cif.gz
# Downloading https://files.rcsb.org/download/6Z0F.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0F.pdb.gz
# Downloading https://files.rcsb.org/download/6Z0F-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0F-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z0Q.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0Q.cif.gz
# Downloading https://files.rcsb.org/download/6Z0Q.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0Q.pdb.gz
# Downloading https://files.rcsb.org/download/6Z0Q-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0Q-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z0R.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0R.cif.gz
# Downloading https://files.rcsb.org/download/6Z0R.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0R.pdb.gz
# Downloading https://files.rcsb.org/download/6Z0R-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0R-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z0Y.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0Y.cif.gz
# Downloading https://files.rcsb.org/download/6Z0Y.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0Y.pdb.gz
# Downloading https://files.rcsb.org/download/6Z0Y-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0Y-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z0Z.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0Z.cif.gz
# Downloading https://files.rcsb.org/download/6Z0Z.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0Z.pdb.gz
# Downloading https://files.rcsb.org/download/6Z0Z-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0Z-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z14.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z14.cif.gz
# Downloading https://files.rcsb.org/download/6Z14.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z14.pdb.gz
# Failed to download https://files.rcsb.org/download/6Z14.pdb.gz
# Downloading https://files.rcsb.org/download/6Z14-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z14-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZLB.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZLB.cif.gz
# Downloading https://files.rcsb.org/download/6ZLB.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZLB.pdb.gz
# Downloading https://files.rcsb.org/download/6ZLB-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZLB-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZLP.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZLP.cif.gz
# Downloading https://files.rcsb.org/download/6ZLP.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZLP.pdb.gz
# Downloading https://files.rcsb.org/download/6ZLP-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZLP-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZMQ.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZMQ.cif.gz
# Downloading https://files.rcsb.org/download/6ZMQ.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZMQ.pdb.gz
# Downloading https://files.rcsb.org/download/6ZMQ-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZMQ-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZO5.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZO5.cif.gz
# Downloading https://files.rcsb.org/download/6ZO5.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZO5.pdb.gz
# Downloading https://files.rcsb.org/download/6ZO5-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZO5-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZO6.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZO6.cif.gz
# Downloading https://files.rcsb.org/download/6ZO6.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZO6.pdb.gz
# Downloading https://files.rcsb.org/download/6ZO6-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZO6-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZO7.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZO7.cif.gz
# Downloading https://files.rcsb.org/download/6ZO7.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZO7.pdb.gz
# Downloading https://files.rcsb.org/download/6ZO7-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZO7-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZO8.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZO8.cif.gz
# Downloading https://files.rcsb.org/download/6ZO8.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZO8.pdb.gz
# Downloading https://files.rcsb.org/download/6ZO8-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZO8-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZO9.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZO9.cif.gz
# Downloading https://files.rcsb.org/download/6ZO9.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZO9.pdb.gz
# Downloading https://files.rcsb.org/download/6ZO9-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZO9-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZOB.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOB.cif.gz
# Downloading https://files.rcsb.org/download/6ZOB.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOB.pdb.gz
# Downloading https://files.rcsb.org/download/6ZOB-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOB-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZOC.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOC.cif.gz
# Downloading https://files.rcsb.org/download/6ZOC.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOC.pdb.gz
# Downloading https://files.rcsb.org/download/6ZOC-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOC-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZOD.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOD.cif.gz
# Downloading https://files.rcsb.org/download/6ZOD.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOD.pdb.gz
# Downloading https://files.rcsb.org/download/6ZOD-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOD-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZOE.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOE.cif.gz
# Downloading https://files.rcsb.org/download/6ZOE.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOE.pdb.gz
# Downloading https://files.rcsb.org/download/6ZOE-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOE-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZOG.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOG.cif.gz
# Downloading https://files.rcsb.org/download/6ZOG.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOG.pdb.gz
# Downloading https://files.rcsb.org/download/6ZOG-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOG-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZOH.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOH.cif.gz
# Downloading https://files.rcsb.org/download/6ZOH.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOH.pdb.gz
# Downloading https://files.rcsb.org/download/6ZOH-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOH-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZOU.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOU.cif.gz
# Downloading https://files.rcsb.org/download/6ZOU.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOU.pdb.gz
# Downloading https://files.rcsb.org/download/6ZOU-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZOU-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZP3.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZP3.cif.gz
# Downloading https://files.rcsb.org/download/6ZP3.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZP3.pdb.gz
# Downloading https://files.rcsb.org/download/6ZP3-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZP3-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZP6.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZP6.cif.gz
# Downloading https://files.rcsb.org/download/6ZP6.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZP6.pdb.gz
# Downloading https://files.rcsb.org/download/6ZP6-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZP6-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZST.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZST.cif.gz
# Downloading https://files.rcsb.org/download/6ZST.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZST.pdb.gz
# Downloading https://files.rcsb.org/download/6ZST-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZST-sf.cif.gz
# Downloading https://files.rcsb.org/download/6ZXO.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZXO.cif.gz
# Downloading https://files.rcsb.org/download/6ZXO.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZXO.pdb.gz
# Downloading https://files.rcsb.org/download/6ZXO-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6ZXO-sf.cif.gz
# Downloading https://files.rcsb.org/download/7A1T.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7A1T.cif.gz
# Downloading https://files.rcsb.org/download/7A1T.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7A1T.pdb.gz
# Downloading https://files.rcsb.org/download/7A1T-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7A1T-sf.cif.gz
# Downloading https://files.rcsb.org/download/7A74.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7A74.cif.gz
# Downloading https://files.rcsb.org/download/7A74.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7A74.pdb.gz
# Downloading https://files.rcsb.org/download/7A74-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7A74-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AC8.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AC8.cif.gz
# Downloading https://files.rcsb.org/download/7AC8.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AC8.pdb.gz
# Downloading https://files.rcsb.org/download/7AC8-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AC8-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AEO.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AEO.cif.gz
# Downloading https://files.rcsb.org/download/7AEO.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AEO.pdb.gz
# Downloading https://files.rcsb.org/download/7AEO-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AEO-sf.cif.gz
# Downloading https://files.rcsb.org/download/7ASW.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7ASW.cif.gz
# Downloading https://files.rcsb.org/download/7ASW.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7ASW.pdb.gz
# Downloading https://files.rcsb.org/download/7ASW-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7ASW-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AUI.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUI.cif.gz
# Downloading https://files.rcsb.org/download/7AUI.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUI.pdb.gz
# Downloading https://files.rcsb.org/download/7AUI-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUI-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AUJ.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUJ.cif.gz
# Downloading https://files.rcsb.org/download/7AUJ.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUJ.pdb.gz
# Downloading https://files.rcsb.org/download/7AUJ-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUJ-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AUK.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUK.cif.gz
# Downloading https://files.rcsb.org/download/7AUK.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUK.pdb.gz
# Downloading https://files.rcsb.org/download/7AUK-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUK-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AUL.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUL.cif.gz
# Downloading https://files.rcsb.org/download/7AUL.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUL.pdb.gz
# Downloading https://files.rcsb.org/download/7AUL-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUL-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AUM.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUM.cif.gz
# Downloading https://files.rcsb.org/download/7AUM.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUM.pdb.gz
# Downloading https://files.rcsb.org/download/7AUM-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUM-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AUN.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUN.cif.gz
# Downloading https://files.rcsb.org/download/7AUN.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUN.pdb.gz
# Downloading https://files.rcsb.org/download/7AUN-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUN-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AUO.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUO.cif.gz
# Downloading https://files.rcsb.org/download/7AUO.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUO.pdb.gz
# Downloading https://files.rcsb.org/download/7AUO-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUO-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AUP.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUP.cif.gz
# Downloading https://files.rcsb.org/download/7AUP.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUP.pdb.gz
# Downloading https://files.rcsb.org/download/7AUP-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUP-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AUQ.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUQ.cif.gz
# Downloading https://files.rcsb.org/download/7AUQ.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUQ.pdb.gz
# Downloading https://files.rcsb.org/download/7AUQ-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUQ-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AUR.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUR.cif.gz
# Downloading https://files.rcsb.org/download/7AUR.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUR.pdb.gz
# Downloading https://files.rcsb.org/download/7AUR-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUR-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AUS.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUS.cif.gz
# Downloading https://files.rcsb.org/download/7AUS.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUS.pdb.gz
# Downloading https://files.rcsb.org/download/7AUS-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUS-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AUT.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUT.cif.gz
# Downloading https://files.rcsb.org/download/7AUT.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUT.pdb.gz
# Downloading https://files.rcsb.org/download/7AUT-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUT-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AUU.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUU.cif.gz
# Downloading https://files.rcsb.org/download/7AUU.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUU.pdb.gz
# Downloading https://files.rcsb.org/download/7AUU-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AUU-sf.cif.gz
# Downloading https://files.rcsb.org/download/7AZY.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AZY.cif.gz
# Downloading https://files.rcsb.org/download/7AZY.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AZY.pdb.gz
# Failed to download https://files.rcsb.org/download/7AZY.pdb.gz
# Downloading https://files.rcsb.org/download/7AZY-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7AZY-sf.cif.gz
# Failed to download https://files.rcsb.org/download/7AZY-sf.cif.gz
# Downloading https://files.rcsb.org/download/7B02.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7B02.cif.gz
# Downloading https://files.rcsb.org/download/7B02.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7B02.pdb.gz
# Downloading https://files.rcsb.org/download/7B02-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7B02-sf.cif.gz
# Downloading https://files.rcsb.org/download/7B7U.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7B7U.cif.gz
# Downloading https://files.rcsb.org/download/7B7U.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7B7U.pdb.gz
# Downloading https://files.rcsb.org/download/7B7U-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7B7U-sf.cif.gz
# Failed to download https://files.rcsb.org/download/7B7U-sf.cif.gz
# Downloading https://files.rcsb.org/download/7B7V.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7B7V.cif.gz
# Downloading https://files.rcsb.org/download/7B7V.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7B7V.pdb.gz
# Downloading https://files.rcsb.org/download/7B7V-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7B7V-sf.cif.gz
# Downloading https://files.rcsb.org/download/7BG6.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BG6.cif.gz
# Downloading https://files.rcsb.org/download/7BG6.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BG6.pdb.gz
# Downloading https://files.rcsb.org/download/7BG6-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BG6-sf.cif.gz
# Failed to download https://files.rcsb.org/download/7BG6-sf.cif.gz
# Downloading https://files.rcsb.org/download/7BG7.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BG7.cif.gz
# Downloading https://files.rcsb.org/download/7BG7.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BG7.pdb.gz
# Downloading https://files.rcsb.org/download/7BG7-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BG7-sf.cif.gz
# Failed to download https://files.rcsb.org/download/7BG7-sf.cif.gz
# Downloading https://files.rcsb.org/download/7BGM.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BGM.cif.gz
# Downloading https://files.rcsb.org/download/7BGM.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BGM.pdb.gz
# Downloading https://files.rcsb.org/download/7BGM-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BGM-sf.cif.gz
# Downloading https://files.rcsb.org/download/7BGN.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BGN.cif.gz
# Downloading https://files.rcsb.org/download/7BGN.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BGN.pdb.gz
# Downloading https://files.rcsb.org/download/7BGN-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BGN-sf.cif.gz
# Downloading https://files.rcsb.org/download/7BKF.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BKF.cif.gz
# Downloading https://files.rcsb.org/download/7BKF.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BKF.pdb.gz
# Downloading https://files.rcsb.org/download/7BKF-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BKF-sf.cif.gz
# Downloading https://files.rcsb.org/download/7BO8.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BO8.cif.gz
# Downloading https://files.rcsb.org/download/7BO8.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BO8.pdb.gz
# Downloading https://files.rcsb.org/download/7BO8-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BO8-sf.cif.gz
# Downloading https://files.rcsb.org/download/7BO9.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BO9.cif.gz
# Downloading https://files.rcsb.org/download/7BO9.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BO9.pdb.gz
# Downloading https://files.rcsb.org/download/7BO9-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BO9-sf.cif.gz
# Downloading https://files.rcsb.org/download/7BOA.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BOA.cif.gz
# Downloading https://files.rcsb.org/download/7BOA.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BOA.pdb.gz
# Downloading https://files.rcsb.org/download/7BOA-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7BOA-sf.cif.gz
# Downloading https://files.rcsb.org/download/7C3O.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C3O.cif.gz
# Downloading https://files.rcsb.org/download/7C3O.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C3O.pdb.gz
# Downloading https://files.rcsb.org/download/7C3O-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C3O-sf.cif.gz
# Downloading https://files.rcsb.org/download/7C3V.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C3V.cif.gz
# Downloading https://files.rcsb.org/download/7C3V.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C3V.pdb.gz
# Downloading https://files.rcsb.org/download/7C3V-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C3V-sf.cif.gz
# Downloading https://files.rcsb.org/download/7C3Z.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C3Z.cif.gz
# Downloading https://files.rcsb.org/download/7C3Z.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C3Z.pdb.gz
# Downloading https://files.rcsb.org/download/7C3Z-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C3Z-sf.cif.gz
# Downloading https://files.rcsb.org/download/7C40.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C40.cif.gz
# Downloading https://files.rcsb.org/download/7C40.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C40.pdb.gz
# Downloading https://files.rcsb.org/download/7C40-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C40-sf.cif.gz
# Downloading https://files.rcsb.org/download/7C41.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C41.cif.gz
# Downloading https://files.rcsb.org/download/7C41.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C41.pdb.gz
# Downloading https://files.rcsb.org/download/7C41-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C41-sf.cif.gz
# Downloading https://files.rcsb.org/download/7C53.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C53.cif.gz
# Downloading https://files.rcsb.org/download/7C53.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C53.pdb.gz
# Downloading https://files.rcsb.org/download/7C53-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7C53-sf.cif.gz
# Downloading https://files.rcsb.org/download/7CHO.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CHO.cif.gz
# Downloading https://files.rcsb.org/download/7CHO.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CHO.pdb.gz
# Downloading https://files.rcsb.org/download/7CHO-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CHO-sf.cif.gz
# Downloading https://files.rcsb.org/download/7CHP.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CHP.cif.gz
# Downloading https://files.rcsb.org/download/7CHP.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CHP.pdb.gz
# Downloading https://files.rcsb.org/download/7CHP-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CHP-sf.cif.gz
# Downloading https://files.rcsb.org/download/7CHQ.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CHQ.cif.gz
# Downloading https://files.rcsb.org/download/7CHQ.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CHQ.pdb.gz
# Downloading https://files.rcsb.org/download/7CHQ-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CHQ-sf.cif.gz
# Downloading https://files.rcsb.org/download/7CHS.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CHS.cif.gz
# Downloading https://files.rcsb.org/download/7CHS.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CHS.pdb.gz
# Downloading https://files.rcsb.org/download/7CHS-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CHS-sf.cif.gz
# Downloading https://files.rcsb.org/download/7CIN.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CIN.cif.gz
# Downloading https://files.rcsb.org/download/7CIN.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CIN.pdb.gz
# Downloading https://files.rcsb.org/download/7CIN-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CIN-sf.cif.gz
# Downloading https://files.rcsb.org/download/7CM9.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CM9.cif.gz
# Downloading https://files.rcsb.org/download/7CM9.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CM9.pdb.gz
# Downloading https://files.rcsb.org/download/7CM9-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CM9-sf.cif.gz
# Downloading https://files.rcsb.org/download/7CP1.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CP1.cif.gz
# Downloading https://files.rcsb.org/download/7CP1.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CP1.pdb.gz
# Downloading https://files.rcsb.org/download/7CP1-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CP1-sf.cif.gz
# Downloading https://files.rcsb.org/download/7CQC.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CQC.cif.gz
# Downloading https://files.rcsb.org/download/7CQC.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CQC.pdb.gz
# Downloading https://files.rcsb.org/download/7CQC-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7CQC-sf.cif.gz
# Downloading https://files.rcsb.org/download/7D2L.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7D2L.cif.gz
# Downloading https://files.rcsb.org/download/7D2L.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7D2L.pdb.gz
# Downloading https://files.rcsb.org/download/7D2L-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7D2L-sf.cif.gz
# Downloading https://files.rcsb.org/download/7D3J.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7D3J.cif.gz
# Downloading https://files.rcsb.org/download/7D3J.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7D3J.pdb.gz
# Downloading https://files.rcsb.org/download/7D3J-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7D3J-sf.cif.gz
# Downloading https://files.rcsb.org/download/7DFT.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DFT.cif.gz
# Downloading https://files.rcsb.org/download/7DFT.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DFT.pdb.gz
# Downloading https://files.rcsb.org/download/7DFT-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DFT-sf.cif.gz
# Downloading https://files.rcsb.org/download/7DFU.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DFU.cif.gz
# Downloading https://files.rcsb.org/download/7DFU.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DFU.pdb.gz
# Downloading https://files.rcsb.org/download/7DFU-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DFU-sf.cif.gz
# Downloading https://files.rcsb.org/download/7DHW.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DHW.cif.gz
# Downloading https://files.rcsb.org/download/7DHW.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DHW.pdb.gz
# Downloading https://files.rcsb.org/download/7DHW-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DHW-sf.cif.gz
# Downloading https://files.rcsb.org/download/7DIY.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DIY.cif.gz
# Downloading https://files.rcsb.org/download/7DIY.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DIY.pdb.gz
# Downloading https://files.rcsb.org/download/7DIY-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DIY-sf.cif.gz
# Downloading https://files.rcsb.org/download/7DJT.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DJT.cif.gz
# Downloading https://files.rcsb.org/download/7DJT.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DJT.pdb.gz
# Downloading https://files.rcsb.org/download/7DJT-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DJT-sf.cif.gz
# Failed to download https://files.rcsb.org/download/7DJT-sf.cif.gz
# Downloading https://files.rcsb.org/download/7DP3.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DP3.cif.gz
# Downloading https://files.rcsb.org/download/7DP3.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DP3.pdb.gz
# Downloading https://files.rcsb.org/download/7DP3-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DP3-sf.cif.gz
# Downloading https://files.rcsb.org/download/7DPD.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DPD.cif.gz
# Downloading https://files.rcsb.org/download/7DPD.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DPD.pdb.gz
# Downloading https://files.rcsb.org/download/7DPD-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DPD-sf.cif.gz
# Downloading https://files.rcsb.org/download/7DVO.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DVO.cif.gz
# Downloading https://files.rcsb.org/download/7DVO.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DVO.pdb.gz
# Downloading https://files.rcsb.org/download/7DVO-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7DVO-sf.cif.gz
# Downloading https://files.rcsb.org/download/7E2W.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7E2W.cif.gz
# Downloading https://files.rcsb.org/download/7E2W.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7E2W.pdb.gz
# Downloading https://files.rcsb.org/download/7E2W-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7E2W-sf.cif.gz
# Downloading https://files.rcsb.org/download/7EKP.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7EKP.cif.gz
# Downloading https://files.rcsb.org/download/7EKP.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7EKP.pdb.gz
# Downloading https://files.rcsb.org/download/7EKP-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7EKP-sf.cif.gz
# Failed to download https://files.rcsb.org/download/7EKP-sf.cif.gz
# Downloading https://files.rcsb.org/download/7EMK.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7EMK.cif.gz
# Downloading https://files.rcsb.org/download/7EMK.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7EMK.pdb.gz
# Downloading https://files.rcsb.org/download/7EMK-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7EMK-sf.cif.gz
# Downloading https://files.rcsb.org/download/7EN0.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7EN0.cif.gz
# Downloading https://files.rcsb.org/download/7EN0.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7EN0.pdb.gz
# Downloading https://files.rcsb.org/download/7EN0-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7EN0-sf.cif.gz
# Failed to download https://files.rcsb.org/download/7EN0-sf.cif.gz
# Downloading https://files.rcsb.org/download/7ENU.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7ENU.cif.gz
# Downloading https://files.rcsb.org/download/7ENU.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7ENU.pdb.gz
# Downloading https://files.rcsb.org/download/7ENU-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7ENU-sf.cif.gz
# Downloading https://files.rcsb.org/download/7EPK.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7EPK.cif.gz
# Downloading https://files.rcsb.org/download/7EPK.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7EPK.pdb.gz
# Downloading https://files.rcsb.org/download/7EPK-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7EPK-sf.cif.gz
# Downloading https://files.rcsb.org/download/7EQU.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7EQU.cif.gz
# Downloading https://files.rcsb.org/download/7EQU.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7EQU.pdb.gz
# Downloading https://files.rcsb.org/download/7EQU-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7EQU-sf.cif.gz
# Downloading https://files.rcsb.org/download/7JXX.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7JXX.cif.gz
# Downloading https://files.rcsb.org/download/7JXX.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7JXX.pdb.gz
# Downloading https://files.rcsb.org/download/7JXX-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7JXX-sf.cif.gz
# Downloading https://files.rcsb.org/download/7JXY.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7JXY.cif.gz
# Downloading https://files.rcsb.org/download/7JXY.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7JXY.pdb.gz
# Downloading https://files.rcsb.org/download/7JXY-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7JXY-sf.cif.gz
# Downloading https://files.rcsb.org/download/7KCN.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7KCN.cif.gz
# Downloading https://files.rcsb.org/download/7KCN.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7KCN.pdb.gz
# Downloading https://files.rcsb.org/download/7KCN-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7KCN-sf.cif.gz
# Downloading https://files.rcsb.org/download/7KCS.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7KCS.cif.gz
# Downloading https://files.rcsb.org/download/7KCS.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/7KCS.pdb.gz
# ...
# Downloading https://files.rcsb.org/download/6W6R-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6W6R-sf.cif.gz
# Downloading https://files.rcsb.org/download/6W6S.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6W6S.cif.gz
# Downloading https://files.rcsb.org/download/6W6S.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6W6S.pdb.gz
# Downloading https://files.rcsb.org/download/6W6S-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6W6S-sf.cif.gz
# Downloading https://files.rcsb.org/download/6W6T.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6W6T.cif.gz
# Downloading https://files.rcsb.org/download/6W6T.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6W6T.pdb.gz
# Downloading https://files.rcsb.org/download/6W6T-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6W6T-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WB3.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WB3.cif.gz
# Downloading https://files.rcsb.org/download/6WB3.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WB3.pdb.gz
# Downloading https://files.rcsb.org/download/6WB3-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WB3-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WBE.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WBE.cif.gz
# Downloading https://files.rcsb.org/download/6WBE.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WBE.pdb.gz
# Downloading https://files.rcsb.org/download/6WBE-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WBE-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WBP.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WBP.cif.gz
# Downloading https://files.rcsb.org/download/6WBP.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WBP.pdb.gz
# Downloading https://files.rcsb.org/download/6WBP-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WBP-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WCU.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WCU.cif.gz
# Downloading https://files.rcsb.org/download/6WCU.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WCU.pdb.gz
# Downloading https://files.rcsb.org/download/6WCU-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WCU-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WH0.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WH0.cif.gz
# Downloading https://files.rcsb.org/download/6WH0.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WH0.pdb.gz
# Downloading https://files.rcsb.org/download/6WH0-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WH0-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WO6.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WO6.cif.gz
# Downloading https://files.rcsb.org/download/6WO6.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WO6.pdb.gz
# Downloading https://files.rcsb.org/download/6WO6-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WO6-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WPC.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WPC.cif.gz
# Downloading https://files.rcsb.org/download/6WPC.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WPC.pdb.gz
# Downloading https://files.rcsb.org/download/6WPC-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WPC-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WSM.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WSM.cif.gz
# Downloading https://files.rcsb.org/download/6WSM.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WSM.pdb.gz
# Downloading https://files.rcsb.org/download/6WSM-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WSM-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WU8.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WU8.cif.gz
# Downloading https://files.rcsb.org/download/6WU8.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WU8.pdb.gz
# Downloading https://files.rcsb.org/download/6WU8-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WU8-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WVW.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WVW.cif.gz
# Downloading https://files.rcsb.org/download/6WVW.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WVW.pdb.gz
# Downloading https://files.rcsb.org/download/6WVW-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WVW-sf.cif.gz
# Downloading https://files.rcsb.org/download/6WX2.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WX2.cif.gz
# Downloading https://files.rcsb.org/download/6WX2.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WX2.pdb.gz
# Downloading https://files.rcsb.org/download/6WX2-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6WX2-sf.cif.gz
# Downloading https://files.rcsb.org/download/6X2L.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6X2L.cif.gz
# Downloading https://files.rcsb.org/download/6X2L.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6X2L.pdb.gz
# Downloading https://files.rcsb.org/download/6X2L-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6X2L-sf.cif.gz
# Failed to download https://files.rcsb.org/download/6X2L-sf.cif.gz
# Downloading https://files.rcsb.org/download/6XBB.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XBB.cif.gz
# Downloading https://files.rcsb.org/download/6XBB.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XBB.pdb.gz
# Downloading https://files.rcsb.org/download/6XBB-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XBB-sf.cif.gz
# Downloading https://files.rcsb.org/download/6XBC.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XBC.cif.gz
# Downloading https://files.rcsb.org/download/6XBC.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XBC.pdb.gz
# Downloading https://files.rcsb.org/download/6XBC-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XBC-sf.cif.gz
# Downloading https://files.rcsb.org/download/6XHD.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XHD.cif.gz
# Downloading https://files.rcsb.org/download/6XHD.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XHD.pdb.gz
# Downloading https://files.rcsb.org/download/6XHD-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XHD-sf.cif.gz
# Downloading https://files.rcsb.org/download/6XHE.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XHE.cif.gz
# Downloading https://files.rcsb.org/download/6XHE.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XHE.pdb.gz
# Downloading https://files.rcsb.org/download/6XHE-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XHE-sf.cif.gz
# Downloading https://files.rcsb.org/download/6XHF.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XHF.cif.gz
# Downloading https://files.rcsb.org/download/6XHF.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XHF.pdb.gz
# Downloading https://files.rcsb.org/download/6XHF-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XHF-sf.cif.gz
# Downloading https://files.rcsb.org/download/6XJ6.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XJ6.cif.gz
# Downloading https://files.rcsb.org/download/6XJ6.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XJ6.pdb.gz
# Downloading https://files.rcsb.org/download/6XJ6-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XJ6-sf.cif.gz
# Downloading https://files.rcsb.org/download/6XJ7.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XJ7.cif.gz
# Downloading https://files.rcsb.org/download/6XJ7.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XJ7.pdb.gz
# Downloading https://files.rcsb.org/download/6XJ7-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XJ7-sf.cif.gz
# Downloading https://files.rcsb.org/download/6XP8.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XP8.cif.gz
# Downloading https://files.rcsb.org/download/6XP8.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XP8.pdb.gz
# Downloading https://files.rcsb.org/download/6XP8-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6XP8-sf.cif.gz
# Downloading https://files.rcsb.org/download/6YLD.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YLD.cif.gz
# Downloading https://files.rcsb.org/download/6YLD.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YLD.pdb.gz
# Downloading https://files.rcsb.org/download/6YLD-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YLD-sf.cif.gz
# Downloading https://files.rcsb.org/download/6YLI.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YLI.cif.gz
# Downloading https://files.rcsb.org/download/6YLI.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YLI.pdb.gz
# Downloading https://files.rcsb.org/download/6YLI-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YLI-sf.cif.gz
# Downloading https://files.rcsb.org/download/6YYU.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YYU.cif.gz
# Downloading https://files.rcsb.org/download/6YYU.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YYU.pdb.gz
# Downloading https://files.rcsb.org/download/6YYU-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YYU-sf.cif.gz
# Downloading https://files.rcsb.org/download/6YYV.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YYV.cif.gz
# Downloading https://files.rcsb.org/download/6YYV.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YYV.pdb.gz
# Downloading https://files.rcsb.org/download/6YYV-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YYV-sf.cif.gz
# Downloading https://files.rcsb.org/download/6YYW.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YYW.cif.gz
# Downloading https://files.rcsb.org/download/6YYW.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YYW.pdb.gz
# Downloading https://files.rcsb.org/download/6YYW-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YYW-sf.cif.gz
# Downloading https://files.rcsb.org/download/6YYX.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YYX.cif.gz
# Downloading https://files.rcsb.org/download/6YYX.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YYX.pdb.gz
# Downloading https://files.rcsb.org/download/6YYX-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YYX-sf.cif.gz
# Downloading https://files.rcsb.org/download/6YYY.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YYY.cif.gz
# Downloading https://files.rcsb.org/download/6YYY.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YYY.pdb.gz
# Downloading https://files.rcsb.org/download/6YYY-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6YYY-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z0C.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0C.cif.gz
# Downloading https://files.rcsb.org/download/6Z0C.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0C.pdb.gz
# Downloading https://files.rcsb.org/download/6Z0C-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0C-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z0L.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0L.cif.gz
# Downloading https://files.rcsb.org/download/6Z0L.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0L.pdb.gz
# Downloading https://files.rcsb.org/download/6Z0L-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0L-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z0M.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0M.cif.gz
# Downloading https://files.rcsb.org/download/6Z0M.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0M.pdb.gz
# Downloading https://files.rcsb.org/download/6Z0M-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z0M-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z2B.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z2B.cif.gz
# Downloading https://files.rcsb.org/download/6Z2B.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z2B.pdb.gz
# Downloading https://files.rcsb.org/download/6Z2B-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z2B-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z6Q.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z6Q.cif.gz
# Downloading https://files.rcsb.org/download/6Z6Q.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z6Q.pdb.gz
# Downloading https://files.rcsb.org/download/6Z6Q-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z6Q-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z6R.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z6R.cif.gz
# Downloading https://files.rcsb.org/download/6Z6R.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z6R.pdb.gz
# Downloading https://files.rcsb.org/download/6Z6R-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z6R-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z79.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z79.cif.gz
# Downloading https://files.rcsb.org/download/6Z79.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z79.pdb.gz
# Downloading https://files.rcsb.org/download/6Z79-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z79-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z7C.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z7C.cif.gz
# Downloading https://files.rcsb.org/download/6Z7C.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z7C.pdb.gz
# Downloading https://files.rcsb.org/download/6Z7C-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z7C-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z7D.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z7D.cif.gz
# Downloading https://files.rcsb.org/download/6Z7D.pdb.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z7D.pdb.gz
# Downloading https://files.rcsb.org/download/6Z7D-sf.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z7D-sf.cif.gz
# Downloading https://files.rcsb.org/download/6Z7E.cif.gz to /content/drive/MyDrive/IonTheFold/ProteinInformation_RAW/40-50k/6Z7E.cif.gz

# %% [markdown]
# #5c. Finally, run the last half of the proteins. (5000 protein ids)
# This will take around 6-8 hours.

# %%
# === Continue using previous dropdown selection and base paths ===
label = dropdown.value
original_file = os.path.join(input_base, id_file_options[label])
output_dir = os.path.join(output_base, "testCollection" if label == "Test file" else label)
script_path = batchDownloadFile

# === Read IDs 5001 to 10000 ===
with open(original_file, 'r') as f:
    content = f.read().strip()
    all_ids = [x.strip() for x in content.split(",") if x.strip()]
    ids_5001_10000 = all_ids[5000:10000]


# === Write to temp file ===
temp_input_file = "/content/ids_5001_10000.txt"
with open(temp_input_file, 'w') as f:
    f.write(",".join(ids_5001_10000))

print(f"🧪 Downloading protein IDs 5001–10000 from: {label}")

# === Ensure output dir exists ===
os.makedirs(output_dir, exist_ok=True)

# === Run download script ===
# !chmod +x "{script_path}"
# !bash "{script_path}" -f "{temp_input_file}" -o "{output_dir}" -c -p -s

# === Count saved *.pdb.gz files
saved_ids = !find "{output_dir}" -type f -name "*.pdb.gz" | wc -l
saved_ids = int(saved_ids[0])
processed = len(ids_5001_10000)
missing = processed - saved_ids

# === Summary
print("----------------------------------------")
print("Summary (IDs 5001–10000):")
print(f"Expected PDB IDs:            {processed}")
print(f"Protein structures saved:    {saved_ids}")
print(f"Missing or failed downloads: {missing}")
print("----------------------------------------")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2853186123.py in <cell line: 0>()
#       1 # === Continue using previous dropdown selection and base paths ===
# ----> 2 label = dropdown.value
#       3 original_file = os.path.join(input_base, id_file_options[label])
#       4 output_dir = os.path.join(output_base, "testCollection" if label == "Test file" else label)
#       5 script_path = batchDownloadFile
#
# NameError: name 'dropdown' is not defined

# %% [markdown]
# ### PDB Download Log Parser: Extract Successfully Downloaded and Failed PDB IDs
# Use this script to automatically extract which PDB files were successfully downloaded and which failed from the batch script output. It helps track download progress and prepare a retry list for failed IDs.

# %%
import re

# Assuming the output of the script is captured in the variable 'script_output'
script_output = """
Downloading https://files.rcsb.org/download/6DBM.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DBM.cif.gz
Downloading https://files.rcsb.org/download/6DBM.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DBM.pdb.gz
Downloading https://files.rcsb.org/download/6DBM-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DBM-sf.cif.gz
Downloading https://files.rcsb.org/download/6DBN.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DBN.cif.gz
Downloading https://files.rcsb.org/download/6DBN.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DBN.pdb.gz
Downloading https://files.rcsb.org/download/6DBN-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DBN-sf.cif.gz
Downloading https://files.rcsb.org/download/6DR1.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DR1.cif.gz
Downloading https://files.rcsb.org/download/6DR1.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DR1.pdb.gz
Downloading https://files.rcsb.org/download/6DR1-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DR1-sf.cif.gz
Downloading https://files.rcsb.org/download/6DR7.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DR7.cif.gz
Downloading https://files.rcsb.org/download/6DR7.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DR7.pdb.gz
Downloading https://files.rcsb.org/download/6DR7-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DR7-sf.cif.gz
Downloading https://files.rcsb.org/download/6DR9.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DR9.cif.gz
Downloading https://files.rcsb.org/download/6DR9.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DR9.pdb.gz
Downloading https://files.rcsb.org/download/6DR9-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DR9-sf.cif.gz
Downloading https://files.rcsb.org/download/6DRB.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DRB.cif.gz
Downloading https://files.rcsb.org/download/6DRB.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DRB.pdb.gz
Downloading https://files.rcsb.org/download/6DRB-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DRB-sf.cif.gz
Downloading https://files.rcsb.org/download/6DRY.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DRY.cif.gz
Downloading https://files.rcsb.org/download/6DRY.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DRY.pdb.gz
Downloading https://files.rcsb.org/download/6DRY-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DRY-sf.cif.gz
Downloading https://files.rcsb.org/download/6DS6.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DS6.cif.gz
Downloading https://files.rcsb.org/download/6DS6.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DS6.pdb.gz
Downloading https://files.rcsb.org/download/6DS6-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DS6-sf.cif.gz
Downloading https://files.rcsb.org/download/6DT6.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DT6.cif.gz
Downloading https://files.rcsb.org/download/6DT6.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DT6.pdb.gz
Downloading https://files.rcsb.org/download/6DT6-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DT6-sf.cif.gz
Downloading https://files.rcsb.org/download/6DUP.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DUP.cif.gz
Downloading https://files.rcsb.org/download/6DUP.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DUP.pdb.gz
Downloading https://files.rcsb.org/download/6DUP-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DUP-sf.cif.gz
Downloading https://files.rcsb.org/download/6DVL.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DVL.cif.gz
Downloading https://files.rcsb.org/download/6DVL.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DVL.pdb.gz
Downloading https://files.rcsb.org/download/6DVL-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DVL-sf.cif.gz
Downloading https://files.rcsb.org/download/6DVM.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DVM.cif.gz
Downloading https://files.rcsb.org/download/6DVM.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DVM.pdb.gz
Downloading https://files.rcsb.org/download/6DVM-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DVM-sf.cif.gz
Downloading https://files.rcsb.org/download/6DVN.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DVN.cif.gz
Downloading https://files.rcsb.org/download/6DVN.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DVN.pdb.gz
Downloading https://files.rcsb.org/download/6DVN-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DVN-sf.cif.gz
Downloading https://files.rcsb.org/download/6DVO.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DVO.cif.gz
Downloading https://files.rcsb.org/download/6DVO.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DVO.pdb.gz
Downloading https://files.rcsb.org/download/6DVO-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DVO-sf.cif.gz
Downloading https://files.rcsb.org/download/6DW2.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DW2.cif.gz
Downloading https://files.rcsb.org/download/6DW2.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DW2.pdb.gz
Downloading https://files.rcsb.org/download/6DW2-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DW2-sf.cif.gz
Downloading https://files.rcsb.org/download/6DWA.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DWA.cif.gz
Downloading https://files.rcsb.org/download/6DWA.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DWA.pdb.gz
Downloading https://files.rcsb.org/download/6DWA-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DWA-sf.cif.gz
Downloading https://files.rcsb.org/download/6DWC.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DWC.cif.gz
Downloading https://files.rcsb.org/download/6DWC.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DWC.pdb.gz
Downloading https://files.rcsb.org/download/6DWC-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DWC-sf.cif.gz
Downloading https://files.rcsb.org/download/6DWI.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DWI.cif.gz
Downloading https://files.rcsb.org/download/6DWI.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DWI.pdb.gz
Downloading https://files.rcsb.org/download/6DWI-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6DWI-sf.cif.gz
Downloading https://files.rcsb.org/download/6EDF.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EDF.cif.gz
Downloading https://files.rcsb.org/download/6EDF.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EDF.pdb.gz
Downloading https://files.rcsb.org/download/6EDF-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EDF-sf.cif.gz
Downloading https://files.rcsb.org/download/6EDI.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EDI.cif.gz
Downloading https://files.rcsb.org/download/6EDI.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EDI.pdb.gz
Downloading https://files.rcsb.org/download/6EDI-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EDI-sf.cif.gz
Downloading https://files.rcsb.org/download/6EE5.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EE5.cif.gz
Downloading https://files.rcsb.org/download/6EE5.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EE5.pdb.gz
Downloading https://files.rcsb.org/download/6EE5-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EE5-sf.cif.gz
Downloading https://files.rcsb.org/download/6EEG.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EEG.cif.gz
Downloading https://files.rcsb.org/download/6EEG.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EEG.pdb.gz
Downloading https://files.rcsb.org/download/6EEG-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EEG-sf.cif.gz
Downloading https://files.rcsb.org/download/6EEK.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EEK.cif.gz
Downloading https://files.rcsb.org/download/6EEK.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EEK.pdb.gz
Downloading https://files.rcsb.org/download/6EEK-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EEK-sf.cif.gz
Downloading https://files.rcsb.org/download/6EEP.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EEP.cif.gz
Downloading https://files.rcsb.org/download/6EEP.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EEP.pdb.gz
Downloading https://files.rcsb.org/download/6EEP-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EEP-sf.cif.gz
Downloading https://files.rcsb.org/download/6EFG.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EFG.cif.gz
Downloading https://files.rcsb.org/download/6EFG.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EFG.pdb.gz
Downloading https://files.rcsb.org/download/6EFG-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EFG-sf.cif.gz
Downloading https://files.rcsb.org/download/6EFH.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EFH.cif.gz
Downloading https://files.rcsb.org/download/6EFH.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EFH.pdb.gz
Downloading https://files.rcsb.org/download/6EFH-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EFH-sf.cif.gz
Downloading https://files.rcsb.org/download/6EIF.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIF.cif.gz
Downloading https://files.rcsb.org/download/6EIF.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIF.pdb.gz
Downloading https://files.rcsb.org/download/6EIF-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIF-sf.cif.gz
Downloading https://files.rcsb.org/download/6EIJ.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIJ.cif.gz
Downloading https://files.rcsb.org/download/6EIJ.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIJ.pdb.gz
Downloading https://files.rcsb.org/download/6EIJ-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIJ-sf.cif.gz
Downloading https://files.rcsb.org/download/6EIL.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIL.cif.gz
Downloading https://files.rcsb.org/download/6EIL.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIL.pdb.gz
Downloading https://files.rcsb.org/download/6EIL-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIL-sf.cif.gz
Downloading https://files.rcsb.org/download/6EIP.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIP.cif.gz
Downloading https://files.rcsb.org/download/6EIP.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIP.pdb.gz
Downloading https://files.rcsb.org/download/6EIP-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIP-sf.cif.gz
Downloading https://files.rcsb.org/download/6EIQ.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIQ.cif.gz
Downloading https://files.rcsb.org/download/6EIQ.pdb.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIQ.pdb.gz
Downloading https://files.rcsb.org/download/6EIQ-sf.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIQ-sf.cif.gz
Downloading https://files.rcsb.org/download/6EIR.cif.gz to /content/drive/MyDrive/IontheFoldPDBstructures/60-70k/6EIR.cif.gz
Downloading https://files.rcsb.org/download/6EIR.pdb.gz to /cont...
"""

# Initialize sets to store downloaded and failed protein IDs
downloaded_ids = set()
failed_ids = set()

# Regex to find protein IDs in the output
download_pattern = re.compile(r'Downloading .*?/(\w{4})\..*? to .*?/\w{4}\..*')
failed_pattern = re.compile(r'Failed to download .*?/(\w{4})\..*')

# Process each line in the script output
for line in script_output.splitlines():
    download_match = download_pattern.search(line)
    if download_match:
        downloaded_ids.add(download_match.group(1))
        continue # Move to the next line if a download is matched

    failed_match = failed_pattern.search(line)
    if failed_match:
        failed_ids.add(failed_match.group(1))

# Remove IDs that were downloaded successfully from the failed set
# This is important because the output shows "Downloading" before "Failed to download" for failed files.
# We only want to count something as 'failed' if it wasn't successfully downloaded.
failed_ids = failed_ids - downloaded_ids

print(f"Number of downloaded files: {len(downloaded_ids)}")
print(f"Number of undownloaded protein IDs: {len(failed_ids)}")

if failed_ids:
    print("\nUndownloaded protein IDs:")
    for pdb_id in failed_ids:
        print(pdb_id)
# Out:
# Number of downloaded files: 32
# Number of undownloaded protein IDs: 0

# %% [markdown]
# #6. Run this script to double check you have the requisite files all set in the Google Drive

# %%
from IPython.display import Image, display

# === Step 6: Verify first 10,000 protein downloads ===
label = dropdown.value
original_file = os.path.join(input_base, id_file_options[label])
output_dir = os.path.join(output_base, "testCollection" if label == "Test file" else label)

with open(original_file, 'r') as f:
    content = f.read().strip()
    all_ids = [x.strip() for x in content.split(",") if x.strip()]
    first_10k_ids = all_ids[:10000]

missing_ids = []
for pdb_id in first_10k_ids:
    expected_file = os.path.join(output_dir, f"{pdb_id}.pdb.gz")
    if not os.path.exists(expected_file):
        missing_ids.append(pdb_id)

found = len(first_10k_ids) - len(missing_ids)

print("----------------------------------------")
print(f"✅ Total expected IDs:        {len(first_10k_ids)}")
print(f"📂 .pdb.gz files found:       {found}")
print(f"❌ Missing protein structures: {len(missing_ids)}")
print("----------------------------------------")

if missing_ids:
    print("Examples of missing PDB IDs:", missing_ids[:10])
else:
    # 🎆 All good — celebrate with fireworks!
    display(Image("https://media.giphy.com/media/xT0xeJpnrWC4XWblEk/giphy.gif"))
